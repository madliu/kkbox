# %%
from speedml import Speedml
import numpy as np

# %%
sml = Speedml('../../Downloads/Predict_churn/kkboxtrainset.csv', 
              '../../Downloads/Predict_churn/kkboxtestset.csv', 
              target = 'is_churn',
              uid = 'msno')

# %%
sml.train.head()
# Out:
#    Unnamed: 0  payment_plan_days  plan_list_price  actual_amount_paid  \
# 0           0                 30              149                 149
# 1           1                 30              180                 180
# 2           2                 30              180                 180
# 3           3                 30               99                  99
# 4           4                 30              149                 149
#
#    is_auto_renew transaction_date membership_expire_date  is_cancel  \
# 0              1       2015-08-09             2019-04-12          0
# 1              1       2017-03-03             2017-04-22          0
# 2              1       2017-03-29             2017-03-31          1
# 3              1       2017-03-23             2017-04-23          0
# 4              1       2015-11-12             2018-06-13          0
#
#    payment_method_id_2  payment_method_id_3    ...     is_discount  \
# ...

# %%
sml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132036 entries, 0 to 1132035
# Data columns (total 56 columns):
# Unnamed: 0                1132036 non-null int64
# payment_plan_days         1132036 non-null int64
# plan_list_price           1132036 non-null int64
# actual_amount_paid        1132036 non-null int64
# is_auto_renew             1132036 non-null int64
# transaction_date          1132036 non-null object
# membership_expire_date    1132036 non-null object
# is_cancel                 1132036 non-null int64
# payment_method_id_2       1132036 non-null int64
# payment_method_id_3       1132036 non-null int64
# payment_method_id_5       1132036 non-null int64
# payment_method_id_6       1132036 non-null int64
# payment_method_id_8       1132036 non-null int64
# payment_method_id_10      1132036 non-null int64
# payment_method_id_11      1132036 non-null int64
# payment_method_id_12      1132036 non-null int64
# payment_method_id_13      1132036 non-null int64
# ...

# %%
#fix this
#sml.plot.distribute()

# %%
sml.plot.correlate()

# %%
sml.feature.impute()
# Out:
# u'Imputed 2688826 empty values to 0.'

# %%
sml.feature.density('bd')
#sml.train[['bd', 'bd_density']].head()

# %%
sml.plot.crosstab('is_churn', 'registered_via')
# Out:
# registered_via   3.0    4.0     7.0     9.0   13.0
# is_churn
# 0               67046  33772  760600  154293  2752
# 1                4193   2849  100033    6493     5

# %%
sml.plot.importance()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-35e9e8351e8b> in <module>()
# ----> 1 sml.plot.importance()
#
# /Users/madli.uutma@ibm.com/anaconda/lib/python2.7/site-packages/speedml/plot.pyc in importance(self)
#     134         X = X.drop([Base.target], axis=1)
#     135         model = ExtraTreesClassifier()
# --> 136         model.fit(X, y)
#     137         self._plot_importance(X.columns, model.feature_importances_)
#     138
#
# /Users/madli.uutma@ibm.com/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if issparse(X):
#
# ...
