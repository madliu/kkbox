# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from datetime import datetime, timedelta

# %% [markdown]
# ## Getting the data

# %%
path= "../../Downloads/Predict_churn/"

# %%
trainset = pd.read_csv(path+"train_v2.csv")

# %%
members = pd.read_csv(path+"members_v2.csv")

# %%
samplesubmission = pd.read_csv(path+"sample_submission_v2.csv")

# %%
transactions = pd.read_csv(path+'transactions_v2.csv',parse_dates=['transaction_date','membership_expire_date'])

# %% [markdown]
# ## Basic info

# %%
members.describe()
# Out:
#                 city             bd  registered_via  registration_init_time
# count  795090.000000  795090.000000   795090.000000            7.950900e+05
# mean        5.253493      11.944989        6.873348            2.013559e+07
# std         6.187004      18.900119        1.825102            2.905877e+04
# min         1.000000   -3152.000000        3.000000            2.004033e+07
# 25%         1.000000       0.000000        7.000000            2.012071e+07
# 50%         1.000000       0.000000        7.000000            2.014111e+07
# 75%         9.000000      26.000000        7.000000            2.016022e+07
# max        22.000000    2016.000000       13.000000            2.017042e+07

# %%
members.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 795090 entries, 0 to 795089
# Data columns (total 6 columns):
# msno                      795090 non-null object
# city                      795090 non-null int64
# bd                        795090 non-null int64
# gender                    318249 non-null object
# registered_via            795090 non-null int64
# registration_init_time    795090 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 36.4+ MB

# %%
members["registered_via"].value_counts()
# Out:
# 7     475062
# 9     182871
# 3      86021
# 4      47686
# 13      3450
# Name: registered_via, dtype: int64

# %% [markdown]
# # Cleaning features

# %%
# Nan values
members['city'] = members.city.apply(lambda x: int(x) if pd.notnull(x) else "NAN")
members['registered_via'] = members.registered_via.apply(lambda x: int(x) if pd.notnull(x) else "NAN")
members['gender']=members['gender'].fillna("NAN")
members.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 795090 entries, 0 to 795089
# Data columns (total 6 columns):
# msno                      795090 non-null object
# city                      795090 non-null int64
# bd                        795090 non-null int64
# gender                    795090 non-null object
# registered_via            795090 non-null int64
# registration_init_time    795090 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 36.4+ MB

# %%
# Age between 10 - 90
members["bd"].where(members["bd"] > 10, np.nan, inplace=True)
members["bd"].where(members["bd"] < 90, np.nan, inplace=True)

# 0 values to Nan?

# %%
members.head()
# Out:
#                                            msno  city    bd  gender  \
# 0  +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1   NaN     NAN
# 1  WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6  32.0  female
# 2  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13  63.0    male
# 3  OoDwiKZM+ZGr9P3fRivavgOtglTEaNfWJO4KaJcTTts=     1   NaN     NAN
# 4  4De1jAxNRABoyRBDZ82U0yEmzYkqeOugRGVNIf92Xb8=     4  28.0  female
#
#    registered_via  registration_init_time
# 0               7                20110914
# 1               9                20110915
# 2               9                20110918
# 3               7                20110918
# 4               9                20110920

# %%
# City - 1 seems to be the default that people select

# %%
# Parsing dates
members["registration_init_time"] = pd.to_datetime(members["registration_init_time"], format='%Y%m%d', errors='ignore')

# %%
# Making gender labels
le = preprocessing.LabelEncoder()
le.fit(members["gender"])
members["gender"]=le.transform(members["gender"])

# Nan values are encoded as 0.

# %%
members.head()
# Out:
#                                            msno  city    bd  gender  \
# 0  +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1   NaN       0
# 1  WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6  32.0       1
# 2  I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13  63.0       2
# 3  OoDwiKZM+ZGr9P3fRivavgOtglTEaNfWJO4KaJcTTts=     1   NaN       0
# 4  4De1jAxNRABoyRBDZ82U0yEmzYkqeOugRGVNIf92Xb8=     4  28.0       1
#
#    registered_via registration_init_time
# 0               7             2011-09-14
# 1               9             2011-09-15
# 2               9             2011-09-18
# 3               7             2011-09-18
# 4               9             2011-09-20

# %%
members.hist(bins=50, figsize=(20,15)) #members.hist
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12cc7e950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b726790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x131a53f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x136984290>]], dtype=object)

# %%
transactions.hist(bins=50, figsize=(20,15)) 
plt.show()

# %%
members["registration_init_time"].groupby([members["registration_init_time"].dt.year, members["registration_init_time"].dt.month]).count().plot(kind="bar")

# %% [markdown]
# # Creating new features

# %%
members["duration_of_membership"] = (members["registration_init_time"]-pd.to_datetime(2017-04-01)).dt.days
# Out:
#                                                 msno  city    bd  gender  \
# 160488  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=     1   NaN       0
# 433057  +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=     1   NaN       0
# 388408  ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=    18  21.0       2
# 404706  ++0/NopttBsaAn6qHZA2AWWrDg7Me7UOMs1vsyo4tSI=     1   NaN       0
# 661640  ++0BJXY8tpirgIhJR14LDM1pnaRosjD1mdO1mIKxlJA=     1   NaN       0
# 49704   ++0nOC7BmrUTtcSboRORfg6ZXTajnBDt1f/SEgH6ONo=    13  25.0       2
# 711427  ++1G0wVY14Lp0VXak1ymLhPUdXPSFJVBnjWwzGxBKJs=     1   NaN       0
# 552924  ++1GCIyXZO7834NjDKmcK1lBVLQi9PsN6sOC7wfW+8g=     1   NaN       0
# 304978  ++38dVm0EHKCOfND6oEal3xFKtqJYZTZJmnpbAOOZBk=     1   NaN       0
# 413044  ++3A6JMzYJeron30GTcDostfXoAl8rTBuB2M8GeVdNU=     1   NaN       0
# 586224  ++3Z+W8OPnpbHYfrKwqRKN1bF83XEbxjdYUolhGdHZg=     5  35.0       1
# 759223  ++3fWHRDC5GWWlovHcrOKWNwZYOjWWkJyeLlL65uv78=     1   NaN       0
# 773346  ++3wqX72HmowxFh5MrHvNi5Ce8D3ldo4zaUL932TYbs=     1   NaN       0
# 106216  ++4RuqBw0Ss6bQU4oMxaRlbBPoWzoEiIZaxPM04Y4+U=     1   NaN       0
# 513586  ++4cUL0b9CfW8cj0A/wfSxQc4k4fcVtWcLqk2UOdpKs=    15  28.0       2
# 179781  ++5HPICzApqAq9mYdGB/mdke0MbubM8yUKLOmrPt4xU=    22  18.0       2
# 446947  ++5nv+2nsvrWM7dOT+ZiWJ5uTZOzQS0NEvqu3jidTjU=     1   NaN       0
# 4215    ++64pHA0OvDq9P9nEAVqSQONHE1ODxEM0KmcazJxKZ8=     1   NaN       0
# 97980   ++6xEqu4JANaRY4GjEfEFtLtqOvZvYPyP3uk/PW9Ces=     1   NaN       0
# 193150  ++7IULiyKbNc8jllqhRuyKZjX1J4mPF4tsudFCJfv4k=     5  38.0       1
# 739442               7             2013-08-05                   15921
# 473964               7             2017-02-10                   17206
# 591978               7             2016-02-02                   16832
# 573018               4             2017-03-15                   17239
# 586000               7             2016-10-20                   17093
# 728411               4             2016-04-16                   16906
# 427413               9             2014-10-14                   16356
# 52179                7             2011-08-23                   15208
# 510632               4             2017-03-05                   17229
# 599395               7             2012-03-06                   15404
# 343171               3             2015-04-30                   16554
# 125794               7             2013-05-15                   15839
# 651904               3             2017-01-29                   17194
#
# [795090 rows x 7 columns]

# %%
members.sort_values("msno")

# %%
# number of transactions
# most common payment method ID across transactions
# most common payment plan days
# how much discount did they get
# what is the price they have paid per order
# How much discount have they gotten on average
# What percent of transactions have had auto-renew?
# Does the last transaction have an auto-renew
# What is the number of days between membership expiration and beginning of April?
# Are only potential users on this list? Or should a group of users be automatically predicted to cancel if the membership expiration date has passed and they have cancelled?
# Out:
#                                            msno  payment_method_id  \
# 0  ++6eU4LsQ3UQ20ILS7d99XK8WbiVgbyYL4FUgzZR134=                 32
# 1  ++lvGPJOinuin/8esghpnqdljm6NXS8m8Zwchc7gOeA=                 41
# 2  +/GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc=                 36
# 3  +/w1UrZwyka4C9oNH3+Q8fUf3fD8R3EwWrx57ODIsqk=                 36
# 4  +00PGzKTYqtnb65mPKPyeHXcZEwqiEzktpQksaaSC3c=                 41
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 90              298                 298              0
# 1                 30              149                 149              1
# 2                 30              180                 180              1
# 3                 30              180                 180              1
# 4                 30               99                  99              1
#
#   transaction_date membership_expire_date  is_cancel
# 0       2017-01-31             2017-05-04          0
# 1       2015-08-09             2019-04-12          0
# 2       2017-03-03             2017-04-22          0
# 3       2017-03-29             2017-03-31          1
# 4       2017-03-23             2017-04-23          0

# %%
tmp1=transactions[transactions.msno=="GXNtXWQVfKrEDqYAzcSw2xSPYMKWNj22m+5XkVQZc= 	"]
tmp1=tmp1.sort_values('transaction_date')
tmp1
# Out:
# Empty DataFrame
# Columns: [msno, payment_method_id, payment_plan_days, plan_list_price, actual_amount_paid, is_auto_renew, transaction_date, membership_expire_date, is_cancel]
# Index: []

# %% [markdown]
# # Merging information

# %%
training_info = pd.merge(trainset, members, how='inner', on="msno")

numeric_training_info = training_info[["is_churn", "bd", "gender", "city", "registered_via", "duration_of_membership"]]
training_info.head()
# Out:
#                                            msno  is_churn  city    bd  gender  \
# 0  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1    13  20.0       2
# 1  t5rqTxCnG7s5VBgEfdkQCezv5KBK7+DMujNibYgylrs=         1    13   NaN       0
# 2  F45GsXJIeLvzUJqz/v4R/6CVYPdek7K4Leu+aqbCRo8=         1     1   NaN       0
# 3  TotbNxPUifAoL9diWEMXcRnBgKDStI/a/SdXcf5WhfQ=         1     4  17.0       1
# 4  wLtPucL8EyK8yUp+F9J1S8Ad/D9CRA8kSB0maalwzjE=         1     4  31.0       1
#
#    registered_via registration_init_time  duration_of_membership
# 0               3             2013-12-23                   16061
# 1               9             2014-03-07                   16135
# 2               3             2014-04-02                   16161
# 3               3             2014-08-12                   16293
# 4               3             2014-08-28                   16309

# %% [markdown]
# # Exploring relationship between features

# %%
numeric_training_info.apply(lambda s: numeric_training_info.corrwith(s))
# WHAT DOES LAMBDA DO?
# How to look at the correlation between dates?
# City and gender are quite highly correlated
# Would be cool to automatically colour this dataframe
# Out:
#                         is_churn        bd    gender      city  \
# is_churn                1.000000 -0.062730  0.071748  0.068654
# bd                     -0.062730  1.000000 -0.026630 -0.012882
# gender                  0.071748 -0.026630  1.000000  0.655500
# city                    0.068654 -0.012882  0.655500  1.000000
# registered_via         -0.060225  0.216964  0.005944  0.022183
# duration_of_membership -0.016193 -0.273721 -0.421963 -0.371879
#
#                         registered_via  duration_of_membership
# is_churn                     -0.060225               -0.016193
# bd                            0.216964               -0.273721
# gender                        0.005944               -0.421963
# city                          0.022183               -0.371879
# registered_via                1.000000               -0.365121
# duration_of_membership       -0.365121                1.000000

# %%
#Registered Via
registered_via_crosstab=pd.crosstab(training_info['registered_via'],training_info['is_churn'])
registered_via_crosstab.plot(kind='bar', stacked=True, grid=True)
registered_via_crosstab["Ratio"] =  registered_via_crosstab[1] / registered_via_crosstab[0]
registered_via_crosstab
# Out:
# is_churn             0     1     Ratio
# registered_via
# 3                64931  3434  0.052887
# 4                32531  2468  0.075866
# 7               435138  2077  0.004773
# 9               151101  5118  0.033871
# 13                2692     2  0.000743

# %%
#city
city_crosstab=pd.crosstab(training_info['city'],training_info['is_churn'])
city_crosstab.plot(kind='bar', stacked=True, grid=True)
city_crosstab["Ratio"] =  city_crosstab[1] / city_crosstab[0]
city_crosstab
# Out:
# is_churn       0     1     Ratio
# city
# 1         405470  3857  0.009512
# 3           3617   113  0.031241
# 4          33666  1069  0.031753
# 5          50257  1528  0.030404
# 6          16909   605  0.035780
# 7           1708    71  0.041569
# 8           5262   178  0.033827
# 9           6414   219  0.034144
# 10          4313   138  0.031996
# 11          5146   215  0.041780
# 12          8155   231  0.028326
# 13         65498  2046  0.031238
# 14         13315   410  0.030792
# 15         25713  1001  0.038930
# 16           717    19  0.026499
# 17          3648    95  0.026042
# 18          5154   163  0.031626
# 19           111     1  0.009009
# 20           538     7  0.013011
# 21          3611   128  0.035447
# 22         27171  1005  0.036988

# %% [markdown]
# # Creating training and test set

# %%
train_set, val_set = train_test_split(members_train, test_size=0.2, random_state=42)

# %% [markdown]
# ## Test filling sample submission with the churn numbers we have

# %%
submission1 = pd.merge(samplesubmission, trainset, how='left', on="msno")

# %%
submission1=submission1[["msno", "is_churn_y"]]
submission1.columns=['msno', 'is_churn']

# %%
submission1= submission1.fillna(0)
submission1.head()
# Out:
#                                            msno  is_churn
# 0  4n+fXlyJvfQnTeKXTWT507Ll4JVYGrOC8LHCfwBmPE4=       0.0
# 1  aNmbC1GvFUxQyQUidCVmfbQ0YeCuwkPzEdQ0RwWyeZM=       0.0
# 2  rFC9eSG/tMuzpre6cwcMLZHEYM89xY02qcz7HL4//jc=       0.0
# 3  WZ59dLyrQcE7ft06MZ5dj40BnlYQY7PHgg/54+HaCSE=       0.0
# 4  aky/Iv8hMp1/V/yQHLtaVuEmmAxkB5GuasQZePJ7NU4=       0.0

# %%
submission1.to_csv("../../Downloads/Predict_churn/submission1.csv", header=True, index=False)
